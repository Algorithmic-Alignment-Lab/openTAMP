# %%
import math

# %%
motion_log = '/Users/phillipchristoffersen/PycharmProjects/openTAMP/opentamp/experiment_logs/namo_objs1_1/pointer_test_log_71/MotionInfo_MotionServer0_log.txt'

# %%
import json

# %%
with open(motion_log) as f:
    data = f.read()

data = data.replace("nan", "-1")
data = data.replace("}", "},")
data = 'var = [' + data + ']'


print(data)
exec(data)
print(var)
# Out:
# var = [{'n_explore': 0,
#  'n_fail_explore': 0,
#  'n_fail_ff': 0,
#  'n_fail_midcond': 0,
#  'n_fail_plans': 0,
#  'n_fail_postcond': 0,
#  'n_fail_precond': 0,
#  'n_fail_rollout_explore': 0,
#  'n_fail_rollout_ff': 0,
#  'n_fail_rollout_midcond': 0,
#  'n_fail_rollout_postcond': 0,
#  'n_fail_rollout_precond': 0,
#  'n_ff': 0,
#  'n_midcond': 0,
#  'n_plans': 0,
#  'n_postcond': 0,
#  'n_precond': 0,
#  'opt duration per ts': -1,
#  'optimization time': -1,
#  'plan length': -1,
#  'time': 0.5109157562255859},
#
# {'n_explore': 0,
#  'n_fail_explore': 0,
#  'n_fail_ff': 0,
#  'n_fail_midcond': 0,
#  'n_fail_plans': 0,
#  'n_fail_postcond': 0,
#  'n_fail_precond': 0,
#  'n_fail_rollout_explore': 0,
#  'n_fail_rollout_ff': 0,
#  'n_fail_rollout_midcond': 0,
#  'n_fail_rollout_postcond': 0,
#  'n_fail_rollout_precond': 0,
#  'n_ff': 0,
#  'n_midcond': 0,
#  'n_plans': 0,
#  'n_postcond': 0,
#  'n_precond': 0,
#  'opt duration per ts': -1,
#  'optimization time': -1,
#  'plan length': -1,
#  'time': 13.226891994476318},
#
# {'n_explore': 0,
#  'n_fail_explore': 0,
#  'n_fail_ff': 0,
#  'n_fail_midcond': 0,
#  'n_fail_plans': 0,
#  'n_fail_postcond': 0,
#  'n_fail_precond': 0,
#  'n_fail_rollout_explore': 0,
#  'n_fail_rollout_ff': 0,
#  'n_fail_rollout_midcond': 0,
#  'n_fail_rollout_postcond': 0,
#  'n_fail_rollout_precond': 0,
#  'n_ff': 0,
#  'n_midcond': 0,
#  'n_plans': 0,
#  'n_postcond': 0,
#  'n_precond': 0,
#  'opt duration per ts': -1,
#  'optimization time': -1,
#  'plan length': -1,
#  'time': 51.63393783569336},
#
# {'n_explore': 0,
#  'n_fail_explore': 0,
#  'n_fail_ff': 0,
#  'n_fail_midcond': 0,
#  'n_fail_plans': 0,
#  'n_fail_postcond': 0,
#  'n_fail_precond': 0,
#  'n_fail_rollout_explore': 0,
#  'n_fail_rollout_ff': 0,
#  'n_fail_rollout_midcond': 0,
#  'n_fail_rollout_postcond': 0,
#  'n_fail_rollout_precond': 0,
#  'n_ff': 0,
#  'n_midcond': 0,
#  'n_plans': 0,
#  'n_postcond': 0,
#  'n_precond': 0,
#  'opt duration per ts': -1,
#  'optimization time': -1,
#  'plan length': -1,
#  'time': 65.03556561470032},
#
# {'n_explore': 0,
#  'n_fail_explore': 0,
#  'n_fail_ff': 0,
#  'n_fail_midcond': 0,
#  'n_fail_plans': 0,
#  'n_fail_postcond': 0,
#  'n_fail_precond': 0,
#  'n_fail_rollout_explore': 0,
#  'n_fail_rollout_ff': 0,
#  'n_fail_rollout_midcond': 0,
#  'n_fail_rollout_postcond': 0,
#  'n_fail_rollout_precond': 0,
#  'n_ff': 0,
#  'n_midcond': 0,
#  'n_plans': 0,
#  'n_postcond': 0,
#  'n_precond': 0,
#  'opt duration per ts': -1,
#  'optimization time': -1,
#  'plan length': -1,
#  'time': 78.12963485717773},
#
# {'n_explore': 0,
#  'n_fail_explore': 0,
#  'n_fail_ff': 0,
#  'n_fail_midcond': 0,
#  'n_fail_plans': 0,
#  'n_fail_postcond': 0,
#  'n_fail_precond': 0,
#  'n_fail_rollout_explore': 0,
#  'n_fail_rollout_ff': 0,
#  'n_fail_rollout_midcond': 0,
#  'n_fail_rollout_postcond': 0,
#  'n_fail_rollout_precond': 0,
#  'n_ff': 0,
#  'n_midcond': 0,
#  'n_plans': 0,
#  'n_postcond': 0,
#  'n_precond': 0,
#  'opt duration per ts': -1,
#  'optimization time': -1,
#  'plan length': -1,
#  'time': 91.62376379966736},
#
# {'n_explore': 0,
#  'n_fail_explore': 0,
#  'n_fail_ff': 0,
#  'n_fail_midcond': 0,
#  'n_fail_plans': 0,
#  'n_fail_postcond': 0,
#  'n_fail_precond': 0,
#  'n_fail_rollout_explore': 0,
#  'n_fail_rollout_ff': 0,
#  'n_fail_rollout_midcond': 0,
#  'n_fail_rollout_postcond': 0,
#  'n_fail_rollout_precond': 0,
#  'n_ff': 0,
#  'n_midcond': 0,
#  'n_plans': 0,
#  'n_postcond': 0,
#  'n_precond': 0,
#  'opt duration per ts': -1,
#  'optimization time': -1,
#  'plan length': -1,
#  'time': 156.55881595611572},
#
# {'n_explore': 0,
#  'n_fail_explore': 0,
#  'n_fail_ff': 0,
#  'n_fail_midcond': 0,
#  'n_fail_plans': 0,
#  'n_fail_postcond': 0,
#  'n_fail_precond': 0,
#  'n_fail_rollout_explore': 0,
#  'n_fail_rollout_ff': 0,
#  'n_fail_rollout_midcond': 0,
#  'n_fail_rollout_postcond': 0,
#  'n_fail_rollout_precond': 0,
#  'n_ff': 0,
#  'n_midcond': 0,
#  'n_plans': 0,
#  'n_postcond': 0,
#  'n_precond': 0,
#  'opt duration per ts': -1,
#  'optimization time': -1,
#  'plan length': -1,
#  'time': 714.7183599472046},
#
# {'n_explore': 0,
#  'n_fail_explore': 0,
#  'n_fail_ff': 0,
#  'n_fail_midcond': 0,
#  'n_fail_plans': 0,
#  'n_fail_postcond': 0,
#  'n_fail_precond': 0,
#  'n_fail_rollout_explore': 0,
#  'n_fail_rollout_ff': 0,
#  'n_fail_rollout_midcond': 0,
#  'n_fail_rollout_postcond': 0,
#  'n_fail_rollout_precond': 0,
#  'n_ff': 0,
#  'n_midcond': 0,
#  'n_plans': 0,
#  'n_postcond': 0,
#  'n_precond': 0,
#  'opt duration per ts': -1,
#  'optimization time': -1,
#  'plan length': -1,
#  'time': 726.6960997581482},
#
# {'n_explore': 0,
#  'n_fail_explore': 0,
#  'n_fail_ff': 0,
#  'n_fail_midcond': 0,
#  'n_fail_plans': 0,
#  'n_fail_postcond': 0,
#  'n_fail_precond': 0,
#  'n_fail_rollout_explore': 0,
#  'n_fail_rollout_ff': 0,
#  'n_fail_rollout_midcond': 0,
#  'n_fail_rollout_postcond': 0,
#  'n_fail_rollout_precond': 0,
#  'n_ff': 0,
#  'n_midcond': 0,
#  'n_plans': 0,
#  'n_postcond': 0,
#  'n_precond': 0,
#  'opt duration per ts': -1,
#  'optimization time': -1,
#  'plan length': -1,
#  'time': 763.0434417724609},
#
# {'n_explore': 0,
#  'n_fail_explore': 0,
#  'n_fail_ff': 0,
#  'n_fail_midcond': 0,
#  'n_fail_plans': 0,
#  'n_fail_postcond': 0,
#  'n_fail_precond': 0,
#  'n_fail_rollout_explore': 0,
#  'n_fail_rollout_ff': 0,
#  'n_fail_rollout_midcond': 0,
#  'n_fail_rollout_postcond': 0,
#  'n_fail_rollout_precond': 0,
#  'n_ff': 0,
#  'n_midcond': 0,
#  'n_plans': 0,
#  'n_postcond': 0,
#  'n_precond': 0,
#  'opt duration per ts': -1,
#  'optimization time': -1,
#  'plan length': -1,
#  'time': 776.3448848724365},
#
# {'n_explore': 0,
#  'n_fail_explore': 0,
#  'n_fail_ff': 0,
#  'n_fail_midcond': 0,
#  'n_fail_plans': 0,
#  'n_fail_postcond': 0,
#  'n_fail_precond': 0,
#  'n_fail_rollout_explore': 0,
#  'n_fail_rollout_ff': 0,
#  'n_fail_rollout_midcond': 0,
#  'n_fail_rollout_postcond': 0,
#  'n_fail_rollout_precond': 0,
#  'n_ff': 0,
#  'n_midcond': 0,
#  'n_plans': 0,
#  'n_postcond': 0,
#  'n_precond': 0,
#  'opt duration per ts': -1,
#  'optimization time': -1,
#  'plan length': -1,
#  'time': 789.981039762497},
#
# {'n_explore': 0,
#  'n_fail_explore': 0,
#  'n_fail_ff': 0,
#  'n_fail_midcond': 0,
#  'n_fail_plans': 0,
#  'n_fail_postcond': 0,
#  'n_fail_precond': 0,
#  'n_fail_rollout_explore': 0,
#  'n_fail_rollout_ff': 0,
#  'n_fail_rollout_midcond': 0,
#  'n_fail_rollout_postcond': 0,
#  'n_fail_rollout_precond': 0,
#  'n_ff': 0,
#  'n_midcond': 0,
#  'n_plans': 0,
#  'n_postcond': 0,
#  'n_precond': 0,
#  'opt duration per ts': -1,
#  'optimization time': -1,
#  'plan length': -1,
#  'time': 841.2071397304535},
#
# ]
# [{'n_explore': 0, 'n_fail_explore': 0, 'n_fail_ff': 0, 'n_fail_midcond': 0, 'n_fail_plans': 0, 'n_fail_postcond': 0, 'n_fail_precond': 0, 'n_fail_rollout_explore': 0, 'n_fail_rollout_ff': 0, 'n_fail_rollout_midcond': 0, 'n_fail_rollout_postcond': 0, 'n_fail_rollout_precond': 0, 'n_ff': 0, 'n_midcond': 0, 'n_plans': 0, 'n_postcond': 0, 'n_precond': 0, 'opt duration per ts': -1, 'optimization time': -1, 'plan length': -1, 'time': 0.5109157562255859}, {'n_explore': 0, 'n_fail_explore': 0, 'n_fail_ff': 0, 'n_fail_midcond': 0, 'n_fail_plans': 0, 'n_fail_postcond': 0, 'n_fail_precond': 0, 'n_fail_rollout_explore': 0, 'n_fail_rollout_ff': 0, 'n_fail_rollout_midcond': 0, 'n_fail_rollout_postcond': 0, 'n_fail_rollout_precond': 0, 'n_ff': 0, 'n_midcond': 0, 'n_plans': 0, 'n_postcond': 0, 'n_precond': 0, 'opt duration per ts': -1, 'optimization time': -1, 'plan length': -1, 'time': 13.226891994476318}, {'n_explore': 0, 'n_fail_explore': 0, 'n_fail_ff': 0, 'n_fail_midcond': 0, 'n_fail_plans': 0, 'n_fail_postcond': 0, 'n_fail_precond': 0, 'n_fail_rollout_explore': 0, 'n_fail_rollout_ff': 0, 'n_fail_rollout_midcond': 0, 'n_fail_rollout_postcond': 0, 'n_fail_rollout_precond': 0, 'n_ff': 0, 'n_midcond': 0, 'n_plans': 0, 'n_postcond': 0, 'n_precond': 0, 'opt duration per ts': -1, 'optimization time': -1, 'plan length': -1, 'time': 51.63393783569336}, {'n_explore': 0, 'n_fail_explore': 0, 'n_fail_ff': 0, 'n_fail_midcond': 0, 'n_fail_plans': 0, 'n_fail_postcond': 0, 'n_fail_precond': 0, 'n_fail_rollout_explore': 0, 'n_fail_rollout_ff': 0, 'n_fail_rollout_midcond': 0, 'n_fail_rollout_postcond': 0, 'n_fail_rollout_precond': 0, 'n_ff': 0, 'n_midcond': 0, 'n_plans': 0, 'n_postcond': 0, 'n_precond': 0, 'opt duration per ts': -1, 'optimization time': -1, 'plan length': -1, 'time': 65.03556561470032}, {'n_explore': 0, 'n_fail_explore': 0, 'n_fail_ff': 0, 'n_fail_midcond': 0, 'n_fail_plans': 0, 'n_fail_postcond': 0, 'n_fail_precond': 0, 'n_fail_rollout_explore': 0, 'n_fail_rollout_ff': 0, 'n_fail_rollout_midcond': 0, 'n_fail_rollout_postcond': 0, 'n_fail_rollout_precond': 0, 'n_ff': 0, 'n_midcond': 0, 'n_plans': 0, 'n_postcond': 0, 'n_precond': 0, 'opt duration per ts': -1, 'optimization time': -1, 'plan length': -1, 'time': 78.12963485717773}, {'n_explore': 0, 'n_fail_explore': 0, 'n_fail_ff': 0, 'n_fail_midcond': 0, 'n_fail_plans': 0, 'n_fail_postcond': 0, 'n_fail_precond': 0, 'n_fail_rollout_explore': 0, 'n_fail_rollout_ff': 0, 'n_fail_rollout_midcond': 0, 'n_fail_rollout_postcond': 0, 'n_fail_rollout_precond': 0, 'n_ff': 0, 'n_midcond': 0, 'n_plans': 0, 'n_postcond': 0, 'n_precond': 0, 'opt duration per ts': -1, 'optimization time': -1, 'plan length': -1, 'time': 91.62376379966736}, {'n_explore': 0, 'n_fail_explore': 0, 'n_fail_ff': 0, 'n_fail_midcond': 0, 'n_fail_plans': 0, 'n_fail_postcond': 0, 'n_fail_precond': 0, 'n_fail_rollout_explore': 0, 'n_fail_rollout_ff': 0, 'n_fail_rollout_midcond': 0, 'n_fail_rollout_postcond': 0, 'n_fail_rollout_precond': 0, 'n_ff': 0, 'n_midcond': 0, 'n_plans': 0, 'n_postcond': 0, 'n_precond': 0, 'opt duration per ts': -1, 'optimization time': -1, 'plan length': -1, 'time': 156.55881595611572}, {'n_explore': 0, 'n_fail_explore': 0, 'n_fail_ff': 0, 'n_fail_midcond': 0, 'n_fail_plans': 0, 'n_fail_postcond': 0, 'n_fail_precond': 0, 'n_fail_rollout_explore': 0, 'n_fail_rollout_ff': 0, 'n_fail_rollout_midcond': 0, 'n_fail_rollout_postcond': 0, 'n_fail_rollout_precond': 0, 'n_ff': 0, 'n_midcond': 0, 'n_plans': 0, 'n_postcond': 0, 'n_precond': 0, 'opt duration per ts': -1, 'optimization time': -1, 'plan length': -1, 'time': 714.7183599472046}, {'n_explore': 0, 'n_fail_explore': 0, 'n_fail_ff': 0, 'n_fail_midcond': 0, 'n_fail_plans': 0, 'n_fail_postcond': 0, 'n_fail_precond': 0, 'n_fail_rollout_explore': 0, 'n_fail_rollout_ff': 0, 'n_fail_rollout_midcond': 0, 'n_fail_rollout_postcond': 0, 'n_fail_rollout_precond': 0, 'n_ff': 0, 'n_midcond': 0, 'n_plans': 0, 'n_postcond': 0, 'n_precond': 0, 'opt duration per ts': -1, 'optimiza ...
